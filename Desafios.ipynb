# %% [markdown]
# #Desafio 1

# %% [markdown]
# Vamos praticar o uso da função print com algumas atividades, solucione os problemas propostos em código:

# %% [markdown]
# 1. Imprima a frase Escola de Dados da Alura!.

# %%
print("Escola de Dados da Alura!")
# Out:
# Escola de Dados da Alura!

# %% [markdown]
# 2. Imprima na tela seu nome e seu sobrenome seguindo a estrutura abaixo:

# %%
print("Nome:Henrique\nSobrenome:Santos")
# Out:
# Nome:Henrique
# Sobrenome:Santos

# %% [markdown]
# 3. Imprima o seu primeiro nome letra a letra. Por exemplo, nome é Mirla, então eu obtenho a seguinte saída:

# %%
print("H")
print("E")
print("N")
print("R")
print("I")
print("Q")
print("U")
print("E")
# Out:
# H
# E
# N
# R
# I
# Q
# U
# E

# %% [markdown]
# 4. Imprima o dia do seu nascimento em formato dia mês ano. Os valores de dia e ano não podem estar entre aspas. O formato deve estar como no exemplo, supondo uma data de aniversário dia 28 de fevereiro de 2003:

# %%
print(26,"fevereiro",2001)
# Out:
# 26 fevereiro 2001

# %% [markdown]
# 5. Imprima em um único print o atual ano que você está fazendo esse curso, o valor do ano deve ser um dado numérico. A saída do print deve ser a seguinte:

# %%
print("Ano atual:",2023)
# Out:
# Ano atual: 2023

# %% [markdown]
# #Desafio 2

# %% [markdown]
# Vamos praticar o uso de vários tipos de variáveis e da função input a partir de algumas atividades. Solucione os problemas propostos em código.

# %% [markdown]
# ##Coleta e amostragem de dados

# %% [markdown]
# 1. Crie um programa que solicite à pessoa usuária digitar seu nome, e imprima “Olá, [nome]!”.

# %%
nome = str(input("Escreva seu nome: " ))
print(f"Olá, {nome}!")
# Out:
# Escreva seu nome: Henrique
# Olá, Henrique!

# %% [markdown]
# 2. Crie um programa que solicite à pessoa usuária digitar seu nome e idade, e imprima “Olá, [nome], você tem [idade] anos.”.

# %%
nome = str(input("Escreva seu nome: " ))
idade = str(input("Escreva sua idade: " ))
print(f"Olá, {nome},você tem {idade} anos.")
# Out:
# Escreva seu nome: Henrique
# Escreva sua idade: 22
# Olá, Henrique,você tem 22 anos!

# %% [markdown]
# 3. Crie um programa que solicite à pessoa usuária digitar seu nome, idade e altura em metros, e imprima “Olá, [nome], você tem [idade] anos e mede [altura] metros!”.

# %%
nome = str(input("Escreva seu nome: " ))
idade = int(input("Escreva sua idade: " ))
altura = float(input("Qual a sua altura(em metros)?: "))
print(f"Olá, {nome},você tem {idade} anos, e mede {altura} metros!")
# Out:
# Escreva seu nome: Henrique
# Escreva sua idade: 22
# Qual a sua altura(em metros)?: 1.75
# Olá, Henrique,você tem 22 anos, e mede 1.75 metros.

# %% [markdown]
# ##Calculadora com operadores

# %% [markdown]
# 1. Crie um programa que solicite dois valores numéricos à pessoa usuária e imprima a soma dos dois valores.

# %%
s1 = float(input("Escolha um número para ser somado: "))
s2 = float(input("Escolha outro número para ser somado: "))
print(f"A soma dos dois é {s1+s2}")
# Out:
# Escolha um número para ser somado: 5
# Escolha outro número para ser somado: 4.3
# A soma dos dois é 9.3

# %% [markdown]
# 2. Crie um programa que solicite três valores numéricos à pessoa usuária e imprima a soma dos três valores.

# %%
s1 = float(input("Escolha o primeiro número para ser somado: "))
s2 = float(input("Escolha o segundo número para ser somado: "))
s3 = float(input("Escolha o terceiro número para ser somado: "))
print(f"A soma dos dois é {s1+s2+s3}")
# Out:
# Escolha o primeiro número para ser somado: 3.5
# Escolha o segundo número para ser somado: 5.4
# Escolha o terceiro número para ser somado: 8.7
# A soma dos dois é 17.6

# %% [markdown]
# 3. Crie um programa que solicite dois valores numéricos à pessoa usuária e imprima a subtração do primeiro pelo o segundo valor.

# %%
s1 = float(input("Escolha o primeiro número para ser subtraido: "))
s2 = float(input("Escolha o segundo número para subtrair: "))
print(f"A subtração dos dois é {s1-s2}")
# Out:
# Escolha o primeiro número para ser subtraido: 4
# Escolha o segundo número para subtrair: 5
# A soma dos dois é -1.0

# %% [markdown]
# 4. Crie um programa que solicite dois valores numéricos à pessoa usuária e imprima a multiplicação dos dois valores.

# %%
s1 = float(input("Escolha o primeiro número para ser multiplicado: "))
s2 = float(input("Escolha o segundo número para ser multiplicado: "))
print(f"A multiplicação dos dois é {s1*s2}")
# Out:
# Escolha o primeiro número para ser multiplicado: 5
# Escolha o segundo número para ser multiplicado: 3
# A multiplicação dos dois é 15.0

# %% [markdown]
# 5. Crie um programa que solicite dois valores numéricos, um numerador e um denominador, e realize a divisão entre os dois valores. Deixe claro que o valor do denominador não pode ser 0.

# %%
s1 = float(input("Escolha o numerador: "))
s2 = float(input("Escolha o denominador: "))
print(f"A divisão dos dois é {s1/s2}")
# Out:
# Escolha o numerador: 15
# Escolha o denominador: 3
# A divisão dos dois é 5.0

# %% [markdown]
# 6. Crie um programa que solicite dois valores numéricos, um operador e uma potência, e realize a exponenciação entre esses dois valores.

# %%
s1 = float(input("Escolha o operador: "))
s2 = float(input("Escolha a potência: "))
print(f"A exponenciação dos dois é {s1**s2}")
# Out:
# Escolha o operador: 3
# Escolha a potência: 2
# A exponenciação dos dois é 9.0

# %% [markdown]
# 7. Crie um programa que solicite dois valores numéricos, um numerador e um denominador e realize a divisão inteira entre os dois valores. Deixe claro que o valor do denominador não pode ser 0.

# %%
s1 = float(input("Escolha o numerador: "))
s2 = float(input("Escolha o denominador: "))
print(f"A divisão inteira dos dois é {s1//s2}")
# Out:
# Escolha o numerador: 5
# Escolha o denominador: 3
# A divisão inteira dos dois é 1.0

# %% [markdown]
# 8. Crie um programa que solicite dois valores numéricos, um numerador e um denominador, e retorne o resto da divisão entre os dois valores. Deixe claro que o valor do denominador não pode ser 0.

# %%
s1 = float(input("Escolha o numerador: "))
s2 = float(input("Escolha o denominador: "))
print(f"O resto da divisão dos dois é {s1%s2}")
# Out:
# Escolha o numerador: 5
# Escolha o denominador: 3
# O resto da divisão dos dois é 2.0

# %% [markdown]
# 9. Crie um código que solicita 3 notas de um estudante e imprima a média das notas.

# %%
s1 = float(input("Coloque a primeira nota: "))
s2 = float(input("Coloque a segunda nota: "))
s3 = float(input("Coloque a terceira nota: "))
print(f"A média das notas é: {(s1+s2+s3)/3}")
# Out:
# Coloque a primeira nota: 8.5
# Coloque a segunda nota: 4.5
# Coloque a terceira nota: 3
# A média das notas é: 5.333333333333333

# %% [markdown]
# 10.
# Crie um código que calcule e imprima a média ponderada dos números 5, 12, 20 e 15 com pesos respectivamente iguais a 1, 2, 3 e 4.

# %%
media_ponderada = (5*1+12*2+20*3+15*4)/(1+2+3+4)
media_ponderada
# Out:
# 14.9

# %% [markdown]
# ##Editando textos

# %% [markdown]
# 1. Crie uma variável chamada “frase” e atribua a ela uma string de sua escolha. Em seguida, imprima a frase na tela.

# %%
frase = "Olá Mundo"
print(frase)
# Out:
# Olá Mundo

# %% [markdown]
# 2. Crie um código que solicite uma frase e depois imprima a frase na tela.

# %%
frase = input("Escreva uma frase: ")
print(frase)
# Out:
# Escreva uma frase: Olá Mundo
# Olá Mundo

# %% [markdown]
# 3. Crie um código que solicite uma frase à pessoa usuária e imprima a mesma frase digitada mas com todas as letras maiúsculas.

# %%
frase = input("Escreve uma frase: ")
print(frase.upper())
# Out:
# Escreve uma frase: Olá Mundo
# OLÁ MUNDO

# %% [markdown]
# 4. Crie um código que solicite uma frase à pessoa usuária e imprima a mesma frase digitada mas com todas as letras minúsculas.

# %%
frase = input("Escreve uma frase: ")
print(frase.lower())
# Out:
# Escreve uma frase: Olá Mundo
# olá mundo

# %% [markdown]
# 5. Crie uma variável chamada “frase” e atribua a ela uma string de sua escolha. Em seguida, imprima a frase sem espaços em branco no início e no fim.

# %%
frase = " Ola "
print(frase.strip())
# Out:
# Ola

# %% [markdown]
# 6. Crie um código que solicite uma frase à pessoa usuária e imprima a mesma frase sem espaços em branco no início e no fim.

# %%
frase = input("Escreve uma frase: ")
print(frase.strip())
# Out:
# Escreve uma frase: Olá Mundo
# Olá Mundo

# %% [markdown]
# 7. Crie um código que solicite uma frase à pessoa usuária e imprima a mesma frase sem espaços em branco no início e no fim e em letras minúsculas.

# %%
frase = input("Escreve uma frase: ")
print(frase.strip().lower())
# Out:
# Escreve uma frase:  OLÁ MUNDO
# olá mundo

# %% [markdown]
# 8. Crie um código que solicite uma frase à pessoa usuária e imprima a mesma frase com todas as vogais “e” trocadas pela letra “f”.

# %%
frase = input("Escreve uma frase: ")
print(frase.strip().replace("e","f").replace("E","F"))
# Out:
# Escreve uma frase: Esse eh meu mundo
# Fssf fh mfu mundo

# %% [markdown]
# 9. Crie um código que solicite uma frase à pessoa usuária e imprima a mesma frase com todas as vogais “a” trocadas pela caractere “@”.

# %%
frase = input("Escreve uma frase: ")
print(frase.strip().replace("a","@"))
# Out:
# Escreve uma frase: Fala Mansa
# F@l@ M@ns@

# %% [markdown]
# 10. Crie um código que solicite uma frase à pessoa usuária e imprima a mesma frase com todas as consoantes “s” trocadas pelo caractere “$”.

# %%
frase = input("Escreve uma frase: ")
print(frase.strip().replace("s","$"))
# Out:
# Escreve uma frase: Esse gosta de suar
# E$$e go$ta de $uar

# %% [markdown]
# #Desafio 3

# %% [markdown]
# Vamos praticar o uso de estruturas condicionais como o if, else e elif a partir de algumas atividades. Agora que estamos avançando nos conteúdos, podemos tornar os desafios mais interessantes: vamos trabalhar com projetos de código! Solucione os problemas de aquecimento para se preparar para os projetos:

# %% [markdown]
# ##Aquecendo na programação

# %% [markdown]
# 1. Escreva um programa que peça à pessoa usuária para fornecer dois números e exibir o número maior.

# %%
n1 = float(input("Informe um número: "))
n2 = float(input("Informe o segundo número: "))
if n1 == n2:
  print("O números são iguais!")
else:
  print("O números são diferentes!")
# Out:
# Informe um número: 3
# Informe o segundo número: 5
# O números são diferentes!

# %% [markdown]
# 2. Escreva um programa que solicite o percentual de crescimento de produção de uma empresa e informe se houve um crescimento (porcentagem positiva) ou decrescimento (porcentagem negativa).

# %%
cresc = float(input("Informe o percentual(%) de crescimento da empresa: "))
if cresc > 0:
  print(f"A empresa cresceu {cresc}%!")
elif cresc == 0:
  print("Não houve crescimento.")
else:
  print("A empresa decresceu {cresc}%!!")
# Out:
# Informe o percentual(%) de crescimento da empresa: 5.4
# A empresa cresceu 5.4%!

# %% [markdown]
# 3. Escreva um programa que determine se uma letra fornecida pela pessoa usuária é uma vogal ou consoante.

# %%
letra = input("Escreva uma letra:")
if letra in ("a","e","i","o","u"):
  print(f"A letra {letra} é uma vogal!")
else:
  print(f"A letra {letra} é uma consoante!")
# Out:
# Escreva uma letra:b
# A letra b é uma consoante!

# %% [markdown]
# 4. Escreva um programa que leia valores médios de preços de um modelo de carro por 3 anos consecutivos e exiba o valor mais alto e mais baixo entre esses três anos.

# %%
n1 = float(input("Informe o preco do carro no ano 1: "))# Preco no primeiro ano
n2 = float(input("Informe o preco do carro no ano 2: "))# Preco no segundo ano
n3 = float(input("Informe o preco do carro no ano 3: "))# Preco no terceiro ano

maior = n1
if n2 > n1:
  maior = n2
if n3 > n1:
  maior = n3

menor = n1
if n2 < n1:
  menor = n2
if n3 < n1:
  menor = n3

print(f"O maior preço foi: {maior}\nO menor preço foi: {menor}")
# Out:
# Informe o preco do carro no ano 1: 50000
# Informe o preco do carro no ano 2: 45000
# Informe o preco do carro no ano 3: 70000
# O maior preço foi: 70000.0
# O menor preço foi: 45000.0

# %% [markdown]
# 5. Escreva um programa que pergunte sobre o preço de três produtos e indique qual é o produto mais barato para comprar.

# %%
n1 = float(input("Informe o preco do primeiro produto: "))# Preco no primeiro iitem
n2 = float(input("Informe o preco do segundo produto: "))# Preco no segundo item
n3 = float(input("Informe o preco do terceiro produto: "))# Preco no terceiro item

if n1 < n2 and n1 < n3:
  print("\nO produto mais barato é o primeiro!")
elif n2 < n1 and n2<n3:
  print("\nO produto mais barato é o segundo!")
else:
  print("\nO produto mais barato é o terceiro!")
# Out:
# Informe o preco do primeiro produto: 7.5
# Informe o preco do segundo produto: 5
# Informe o preco do terceiro produto: 4.3
#
# O produto mais barato é o terceiro!

# %% [markdown]
# 6. Escreva um programa que leia três números e os exiba em ordem decrescente.

# %%
n1 = int(input("Informe o primeiro número: "))
n2 = int(input("Informe o segundo número: "))
n3 = int(input("Informe o terceiro número: "))

if n1 < n2 and n1 < n3 and n2 < n3:
  print(f"{n1} {n2} {n3}")
elif n1 < n2 and n1 < n3 and n2 > n3:
  print(f"{n1} {n3} {n2}")
elif n2 < n1 and n2 < n3 and n1 < n3:
  print(f"{n2} {n1} {n3}")
elif n2 < n1 and n2 < n3 and n1 > n3:
  print(f"{n2} {n3} {n1}")
elif n3 < n1 and n3 < n2 and n2 > n1:
  print(f"{n3} {n1} {n2}")
else:
  print(f"{n3} {n2} {n1}")
# Out:
# Informe o primeiro número: 47
# Informe o segundo número: 62
# Informe o terceiro número: 3
# 3 47 62

# %% [markdown]
# 7. Escreva um programa que pergunte em qual turno a pessoa usuária estuda ("manhã", "tarde" ou "noite") e exiba a mensagem "Bom Dia!", "Boa Tarde!", "Boa Noite!", ou "Valor Inválido!", conforme o caso.

# %%
turno = input("Qual seu turno(manhã, tarde ou noite): ")

if "manhã" in turno:
  print("Bom dia!")
elif "tarde" in turno:
  print("Boa tarde!")
elif "noite" in turno:
  print("Boa noite!")
else:
  print("Valor inválido!")
# Out:
# Qual seu turno(manhã, tarde ou noite): ola
# Valor inválido!

# %% [markdown]
# 8. Escreva um programa que peça um número inteiro à pessoa usuária e determine se ele é par ou ímpar. Dica: Você pode utilizar o operador módulo %.

# %%
num = int(input("Escreva um número: "))

if num%2 == 0:
  print(f"O número {num} é par!")
else:
  print(f"O número {num} é impar!")
# Out:
# Escreva um número: 22
# O número 22 é par!

# %% [markdown]
# 9. Escreva um programa que peça um número à pessoa usuária e informe se ele é inteiro ou decimal.

# %%
num = float(input("Digite um número inteiro ou decimal: "))

if num%1==0:
  print("O número é inteiro!")
else:
  print("O número é decimal!")
# Out:
# Digite um número inteiro ou decimal: 5.4
# O número é decimal!

# %% [markdown]
# ##Momento dos projetos

# %% [markdown]
# 10. Um programa deve ser escrito para ler dois números e, em seguida, perguntar à pessoa usuária qual operação ele deseja realizar. O resultado da operação deve incluir informações sobre o número - se é par ou ímpar, positivo ou negativo e inteiro ou decimal.

# %%
n1 = float(input("Informe o primeiro número: "))
n2 = float(input("\nInforme o segundo número: "))

oper = int(input("\nEscolha a operação desejada:\n - 1 - Multiplicação\n - 2 - Soma\n - 3 - Subtração\n - 4 - Divisão\nEscolha: "))

if oper == 1:
  mul = n1*n2
  print(f"\nA multiplicação dos dois números é: {mul}")
  if mul%2==0:
    print(f"O número {mul} é par!")
  else:
    print(f"O número {mul} é impar!")
  if mul>0:
    print(f"O número {mul} é positivo!")
  else:
    print(f"O número {mul} é negativo!")
  if mul%1==0:
    print(f"O número {mul} é inteiro!")
  else:
    print(f"O número {mul} é decimal!")

if oper == 2:
  mul = n1+n2
  print(f"\nA soma dos dois números é: {mul}")
  if mul%2==0:
    print(f"O número {mul} é par!")
  else:
    print(f"O número {mul} é impar!")
  if mul>0:
    print(f"O número {mul} é positivo!")
  else:
    print(f"O número {mul} é negativo!")
  if mul%1==0:
    print(f"O número {mul} é inteiro!")
  else:
    print(f"O número {mul} é decimal!")

if oper == 3:
  mul = n1-n2
  print(f"\nA subtração dos dois números é: {mul}")
  if mul%2==0:
    print(f"O número {mul} é par!")
  else:
    print(f"O número {mul} é impar!")
  if mul>0:
    print(f"O número {mul} é positivo!")
  else:
    print(f"O número {mul} é negativo!")
  if mul%1==0:
    print(f"O número {mul} é inteiro!")
  else:
    print(f"O número {mul} é decimal!")

if oper == 4:
  mul = n1/n2
  print(f"\nA divisão dos dois números é: {mul}")
  if mul%2==0:
    print(f"O número {mul} é par!")
  else:
    print(f"O número {mul} é impar!")
  if mul>0:
    print(f"O número {mul} é positivo!")
  else:
    print(f"O número {mul} é negativo!")
  if mul%1==0:
    print(f"O número {mul} é inteiro!")
  else:
    print(f"O número {mul} é decimal!")
# Out:
# Informe o primeiro número: 5
#
# Informe o segundo número: 7
#
# Escolha a operação desejada:
#  - 1 - Multiplicação
#  - 2 - Soma
#  - 3 - Subtração
#  - 4 - Divisão
# Escolha: 4
#
# A divisão dos dois números é: 0.7142857142857143
# O número 0.7142857142857143 é impar!
# O número 0.7142857142857143 é positivo!
# O número 0.7142857142857143 é decimal!

# %% [markdown]
# 11. Escreva um programa que peça à pessoa usuária três números que representam os lados de um triângulo. O programa deve informar se os valores podem ser utilizados para formar um triângulo e, caso afirmativo, se ele é equilátero, isósceles ou escaleno. Tenha em mente algumas dicas:
#   * Três lados formam um triângulo quando a soma de quaisquer dois lados for maior que o terceiro;
#   * Triângulo Equilátero: três lados iguais;
#   * Triângulo Isósceles: quaisquer dois lados iguais;
#   * Triângulo Escaleno: três lados diferentes.

# %%
v1 = int(input("Insira o valor do primeiro vértice:"))
v2 = int(input("Insira o valor do segundo vértice:"))
v3 = int(input("Insira o valor do terceiro vértice:"))

if v1 == v2 and v1 == v3 and v2 == v3:
  print("O triângulo é equilátero!")
elif v1 != v2 and v1 != v3 and v2 != v3:
  print("O triângulo é escaleno!")
else:
  print("O triângulo é isóceles!")
# Out:
# Insira o valor do primeiro vértice:3
# Insira o valor do segundo vértice:3
# Insira o valor do terceiro vértice:4
# O triângulo é isóceles!

# %% [markdown]
# 12. Um estabelecimento está vendendo combustíveis com descontos variados. Para o etanol, se a quantidade comprada for até 15 litros, o desconto será de 2% por litro. Caso contrário, será de 4% por litro. Para o diesel, se a quantidade comprada for até 15 litros, o desconto será de 3% por litro. Caso contrário, será de 5% por litro. O preço do litro de diesel é R$ 2,00 e o preço do litro de etanol é R$ 1,70. Escreva um programa que leia a quantidade de litros vendidos e o tipo de combustível (E para etanol e D para diesel) e calcule o valor a ser pago pelo cliente. Tenha em mente algumas dicas:
#
#   * O do valor do desconto será a multiplicação entre preço do litro, quantidade de litros e o valor do desconto.
#   * O valor a ser pago por um cliente será o resultado da multiplicação do preço do litro pela quantidade de litros menos o valor de desconto resultante do cálculo.

# %%
tipo = input("Escolha o tipo de combustível:\n - E - Etanol\n - D - Diesel\nEscolha: ")

if tipo == "E":
  litros = int(input("\nQuantos litros serão colocados: "))
  if litros < 15:
    valor = litros*2*0.98
    print(f"O valor pago será: {valor:0.2f}")
  else:
    valor = litros*2*0.96
    print(f"O valor pago será: {valor:0.2f}")

if tipo == "D":
  litros = int(input("\nQuantos litros serão colocados: "))
  if litros < 15:
    valor = litros*1.7*0.97
    print(f"O valor pago será: {valor:0.2f}")
  else:
    valor = litros*1.7*0.95
    print(f"O valor pago será: {valor:0.2f}")
# Out:
# Escolha o tipo de combustível:
#  - E - Etanol
#  - D - Diesel
# Escolha: E
#
# Quantos litros serão colocados: 35
# O valor pago será: 67.20

# %% [markdown]
# 13. Em uma empresa de venda de imóveis você precisa criar um código que analise os dados de vendas anuais para ajudar a diretoria na tomada de decisão. O código precisa coletar os dados de quantidade de venda durante os anos de 2022 e 2023 e fazer um cálculo de variação percentual. A partir do valor da variação, deve ser enviada às seguintes sugestões:
#
#   * Para variação acima de 20%: bonificação para o time de vendas.
#   * Para variação entre 2% e 20%: pequena bonificação para time de vendas.
#   * Para variação entre 2% e -10%: planejamento de políticas de incentivo às vendas.
#   * Para bonificações abaixo de -10%: corte de gastos.

# %%
valor1 = float(input("Coloque a quantidade vendida em 2022: "))
valor2 = float(input("Coloque a quantidade vendida em 2023: "))

varia = ((valor2 - valor1)/valor1)*100

if varia >= 0.2:
  print(f"O resultado foi um aumento de {varia:0.2f}%!\nBonificação para o time de vendas!")
elif 0.02 <= varia < 0.2:
  print(f"O resultado foi um aumento de {varia:0.2f}%!\nPequena bonificação para o time de vendas.")
elif -0.1 <= varia < 0.02:
  print(f"O resultado foi um regresso de {varia:0.2f}%!\nPlanejamento de política de incentivo às vendas.")
else:
  print(f"O resultado foi um regresso de {varia:0.2f}%!\nCorte de gastos.")
# Out:
# Coloque a quantidade vendida em 2022: 4500
# Coloque a quantidade vendida em 2023: 5000
# O resultado foi um aumento de 11.11%!
# Bonificação para o time de vendas!

# %% [markdown]
# #Desafio 4

# %% [markdown]
# Vamos praticar o uso de estruturas de repetição como o while e o for a partir de algumas atividades. Agora que estamos avançando nos conteúdos, podemos tornar os desafios mais interessantes: vamos trabalhar com projetos de código! Solucione os problemas de aquecimento para se preparar para os projetos:

# %% [markdown]
# ##Aquecendo na programação

# %% [markdown]
# 1. Escreva um programa que peça dois números inteiros e imprima todos os números inteiros entre eles.

# %%
n1 = int(input("Escreva o primeiro numero inteiro: "))
n2 = int(input("Escreva o segundo numero inteiro: "))

if n1>n2:
  for i in range(n2+1,n1):
    print(i)
else:
  for i in range(n1+1,n2):
    print(i)
# Out:
# Escreva o primeiro numero inteiro: 3
# Escreva o segundo numero inteiro: 8
# 4
# 5
# 6
# 7

# %% [markdown]
# 2. Escreva um programa para calcular quantos dias levará para a colônia de uma bactéria A ultrapassar ou igualar a colônia de uma bactéria B, com base nas taxas de crescimento de 3% e 1,5% respectivamente. Considere que a colônia A inicia com 4 elementos e a colônia B com 10 elementos.

# %%
#Adicionando as condicoes iniciais
A = 4
B =10

#Adicionando as taxas de crescimento de cada uma
taxa_a = 0.03
taxa_b = 0.015

#contador que contara os dias
contador = 0

#Loop que ira nos informar quando A ultrapassara B
while A <= B:
  contador += 1
  A *= 1 + taxa_a
  B *= 1 + taxa_b

#Envia a quantidade de dia e de individuos
print (f"O numero de dias para que a colonia A ultrapasse a segunda eh {contador} dias.")
print (f"Ja a quantidade de individuo eh {A}")
# Out:
# O numero de dias para que ambas se igualem eh 63 dias.
# Ja a quantidade de individuo eh 25.75165514029839

# %% [markdown]
# 3. Para tratar uma quantidade de 15 dados de avaliações de pessoas usuárias de um serviço da empresa, precisamos verificar se as notas são válidas. Então, escreva um programa que vai receber a nota de 0 a 5 de todos os dados e verificar se é um valor válido. Caso seja inserido uma nota acima de 5 ou abaixo de 0, repita até que a pessoa usuária insira um valor válido.

# %%
#Contador para calculador a quantidade de avaliacoes
contador = 0
avali = 4

#Contador sera reduzido a 4 para simplicar o trabalho
while contador != avali:#Para alterar a quantidade de avaliacoes apenas mudar essse numero
  nota = int(input("Escreva sua nota (0 a 5): "))
  if 0 <= nota <=5:
    contador += 1
    print(f"\nFaltam {avali - contador} notas\n")
  else:
    print("\nNumero invalido!\n")
    continue
# Out:
# Escreva sua nota (0 a 5): 5
#
# Faltam 3 notas
#
# Escreva sua nota (0 a 5): 3
#
# Faltam 2 notas
#
# Escreva sua nota (0 a 5): 8
#
# Numero invalido!
#
# Escreva sua nota (0 a 5): 3
#
# Faltam 1 notas
#
# Escreva sua nota (0 a 5): 1
#
# Faltam 0 notas

# %% [markdown]
# 4. Desenvolva um programa que leia um conjunto indeterminado de temperaturas em Celsius e faça uma análise. Portanto, escreva um programa que leia temperaturas e informe a média delas. A leitura deve ser encerrada ao ser enviado o valor -273°C.

# %%
#Definimos a temperatura inicial do programa
temp_inicial = float(input("Escreva a temperatura inicial (em Celsius): "))
soma = temp_inicial #Acrescentamos a soma o valor da temperatura inicial
temp = 0  #declarando a variavel temperatura e um contador para auxiliar no
contador = 1 # calculo da media

while temp != -273 and temp_inicial != -273: #Caso o valor indicado seja -273, o
  contador += 1                              #programa continua
  temp = float(input("Escreva a temperatura seguinte em Celsius: "))
  soma += temp
  media = soma/contador
  print(f"A media das temperaturas eh(em Celsius): {media:0.2f}")

print("Leitura encerrada!")
# Out:
# Escreva a temperatura inicial (em Celsius): 24
# Escreva a temperatura seguinte em Celsius: 40
# A media das temperaturas eh(em Celsius): 32.00
# Escreva a temperatura seguinte em Celsius: 12
# A media das temperaturas eh(em Celsius): 25.33
# Escreva a temperatura seguinte em Celsius: -273
# A media das temperaturas eh(em Celsius): -49.25
# Leitura encerrada!

# %% [markdown]
# 5. Escreva um programa que calcule o fatorial de um número inteiro fornecido pela pessoa usuária. O fatorial de um número inteiro é a multiplicação desse número por todos os seus antecessores até o número 1. Por exemplo, o fatorial de 5 é 5 x 4 x 3 x 2 x 1 = 120.

# %%
#Pedimos um valor inteiro inicial
n = int(input("Escolha um numero para calcular seu fatorial: "))
mult = n #Carregamos  a variavel que sera multiplicada

for i in range(n-1,0,-1):
  mult *= i               #Pega o valor n e multiplica pelo anterior, ate chegar a 1

print(f"O valor fatorial de {n} eh: {mult}")
# Out:
# Escolha um numero para calcular seu fatorial: 4
# O valor fatorial de 4 eh: 24

# %% [markdown]
# ##Momento dos projetos

# %% [markdown]
# 1. Escreva um programa que gere a tabuada de um número inteiro de 1 a 10, de acordo com a escolha da pessoa usuária. Como exemplo, para o número 2, a tabuada deve ser mostrada no seguinte formato:

# %%
n = int(input("Escolha o numero que deseja descobria a tabuada: "))

print(f"A tabuada de {n} eh")

for i in range(1,11):
  print(f"{n} x {i} = {n*i}")
# Out:
# Escolha o numero que deseja descobria a tabuada: 4
# A tabuada de 4 eh
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# 4 x 10 = 40

# %% [markdown]
# 2. Os números primos possuem várias aplicações dentro da Ciência de Dados, por exemplo, na criptografia e segurança. Um número primo é aquele que é divisível apenas por um e por ele mesmo. Faça um programa que peça um número inteiro e determine se ele é ou não um número primo.

# %%
n = int(input("Escreva um numero para ver se ele eh primo: "))

if 1 < n:
  for i in range(2,n):
    if n%i == 00:
      print(f"O numero {n} nao eh primo!")
      break
  else:
    print(f"O numero {n} eh primo!")


else:
  print(f"O numero {n} nao eh primo!")
# Out:
# Escreva um numero para ver se ele eh primo: 73
# O numero 73 eh primo!

# %% [markdown]
# 3. Vamos entender a distribuição de idades de pensionistas de uma empresa de previdência. Escreva um programa que leia as idades de uma quantidade não informada de clientes e mostre a distribuição em intervalos de [0-25], [26-50], [51-75] e [76-100]. Encerre a entrada de dados com um número negativo.

# %%
dist1 = 0 #[0-25]
dist2 = 0 #[26-50]
dist3 = 0 #[51-75]
dist4 = 0 #[76-100]
idade = 0 #contador

while idade >= 0:
  idade = int(input("Insira uma idade: "))
  if 0 <= idade <= 25:
    dist1 += 1
  elif 25 < idade <= 50:
    dist2 += 1
  elif 50 < idade <= 75:
    dist3 += 1
  elif 75 < idade <= 100:
    dist4 += 1

print("Contagem encerrada!")
print("\nA distribuição das idade é: \n")

print(f"\n\t[0-25]\t[26-50]\t[51-75]6\t[76-100]\n")
print(f"\t{dist1} \t{dist2} \t{dist3} \t{dist4}")
# Out:
# Insira uma idade: 23
# Insira uma idade: 54
# Insira uma idade: 76
# Insira uma idade: 23
# Insira uma idade: 12
# Insira uma idade: 43
# Insira uma idade: 5
# Insira uma idade: 76
# Insira uma idade: 32
# Insira uma idade: 87
# Insira uma idade: 32
# Insira uma idade: 5
# Insira uma idade: 2
# Insira uma idade: 65
# Insira uma idade: 4
# Insira uma idade: 45
# Insira uma idade: 34
# Insira uma idade: -1
# Contagem encerrada!
#
# A distribuição das idade é:
#
#
# 	[0-25]	[26-50]	[51-75]	[76-100]
#
# 	7 	5 	2 	3

# %% [markdown]
# 4. Em uma eleição para gerência em uma empresa com 20 funcionários, existem quatro candidatos. Escreva um programa que calcule o vencedor da eleição. A votação ocorreu da seguinte maneira:
#   * Cada funcionário votou em um dos quatro candidatos (representados pelos números 1, 2, 3 e 4).
#   * Também foram contabilizados os votos nulos (representado pelo número 5) e os votos em branco (representado pelo número 6).
#
#   Ao final da votação, o programa deve exibir o total de votos para cada candidato, o número de votos nulos e o número de votos em branco. Além disso, deve calcular e exibir a porcentagem de votos nulos em relação ao total de votos e a porcentagem de votos em branco em relação ao total de votos.

# %%
voto = 0 #Variavel para o voto
cand1 = 0 #Contador de votos para o candidato 1
cand2 = 0 #Contador de votos para o candidato 2
cand3 = 0 #Contador de votos para o candidato 3
cand4 = 0 #Contador de votos para o candidato 4
brancos = 0 #Contador de votos em branco
nulos = 0 #Contador de votos nulos
cont = 0 #Contagem de votos, devem ser  20
max = 20

while cont != max:
  voto = int(input("Insira o numero do candidato que quer votar: "))
  if voto == 1:
    cand1 += 1
  elif voto ==2:
    cand2 += 1
  elif voto ==3:
    cand3 += 1
  elif voto == 4:
    cand4 += 1
  elif voto ==5:
    nulos += 1
  elif voto == 6:
    brancos += 1
  else:
    print("O valor adicionado nao eh valido!")
    continue
  cont += 1

print("A votacao acabou!\n")
6
print("A ditribuicao da votacao eh:\n")
print("\t1\t2\t3\t4\t5\t6")
print(f"\t{cand1}\t{cand2}\t{cand3}\t{cand4}\t{nulos}\t{brancos}")
print(f"\nPorcentagem de votos nulos em relacao ao total: {(nulos/max)*100}%")
print(f"Porcentagem de votos brancos em relacao ao total: {(brancos/max)*100}%")
# Out:
# Insira o numero do candidato que quer votar: 5
# Insira o numero do candidato que quer votar: 6
# Insira o numero do candidato que quer votar: 7
# O valor adicionado nao eh valido!
# Insira o numero do candidato que quer votar: 2
# Insira o numero do candidato que quer votar: 4
# Insira o numero do candidato que quer votar: 2
# Insira o numero do candidato que quer votar: 5
# Insira o numero do candidato que quer votar: 1
# Insira o numero do candidato que quer votar: 1
# Insira o numero do candidato que quer votar: 5
# Insira o numero do candidato que quer votar: 3
# Insira o numero do candidato que quer votar: 8
# O valor adicionado nao eh valido!
# Insira o numero do candidato que quer votar: 4
# Insira o numero do candidato que quer votar: 6
# Insira o numero do candidato que quer votar: 5
# Insira o numero do candidato que quer votar: 2
# Insira o numero do candidato que quer votar: 4
# Insira o numero do candidato que quer votar: 1
# ...

# %% [markdown]
# #Desafio 5

# %% [markdown]
# Vamos praticar o uso de estruturas de dados como as listas e os dicionários a partir de algumas atividades. Agora que estamos avançando nos conteúdos, podemos tornar os desafios mais interessantes: vamos trabalhar com projetos de código! Solucione os problemas de aquecimento para se preparar para os projetos:

# %% [markdown]
# ##Aquecendo na programação

# %% [markdown]
# 1. Faça um programa que tenha a seguinte lista contendo os valores de gastos de uma empresa de papel [2172.54, 3701.35, 3518.09, 3456.61, 3249.38, 2840.82, 3891.45, 3075.26, 2317.64, 3219.08]. Com esses valores, faça um programa que calcule a média de gastos. Dica, use as funções built-in sum() e len().

# %%
gastos = [2172.54, 3701.35, 3518.09, 3456.61, 3249.38, 2840.82, 3891.45, 3075.26, 2317.64, 3219.08]

media_gastos = sum(gastos)/len(gastos)

print(f"A media dos gastos eh {media_gastos}")
# Out:
# A media dos gastos eh 3144.222

# %% [markdown]
# 2. Com os mesmos dados da questão anterior, defina quantas compras foram acima de 3000 reais e calcule a porcentagem quanto ao total de compras.

# %%
count=0

for i in range(1,len(gastos)):
  if gastos[i] > 3000:
    count += 1

print(f"Cerca de {count/len(gastos)*100}% foram compras acima de 3000.")
# Out:
# Cerca de 70.0% foram compras acima de 3000.

# %% [markdown]
# 3. Faça um código que colete em uma lista 5 números inteiros quaisquer e imprima a lista. Exemplo: [1,4,7,2,4].

# %%
lista = []
for i in range(1,6):
  n = int(input("Escreva um numere inteiro para ser adicionado a lista: "))
  lista.append(n)

print(f"\nLista com os numeros inseridos: {lista}")
# Out:
# Escreva um numere inteiro para ser adicionado a lista: 4
# Escreva um numere inteiro para ser adicionado a lista: 5
# Escreva um numere inteiro para ser adicionado a lista: 6
# Escreva um numere inteiro para ser adicionado a lista: 3
# Escreva um numere inteiro para ser adicionado a lista: 2
#
# Lista com os numeros inseridos: [4, 5, 6, 3, 2]

# %% [markdown]
# 4. Colete novamente 5 inteiros e imprima a lista em ordem inversa à enviada.

# %%
lista = []
for i in range(1,6):
  n = int(input("Escreva um numere inteiro para ser adicionado a lista: "))
  lista.append(n)

print(f"\nLista com os numeros invertidos: {lista[::-1]}")
# Out:
# Escreva um numere inteiro para ser adicionado a lista: 5
# Escreva um numere inteiro para ser adicionado a lista: 4
# Escreva um numere inteiro para ser adicionado a lista: 3
# Escreva um numere inteiro para ser adicionado a lista: 2
# Escreva um numere inteiro para ser adicionado a lista: 1
#
# Lista com os numeros invertidos: [1, 2, 3, 4, 5]

# %% [markdown]
# 5. Faça um programa que, ao inserir um número qualquer, criará uma lista contendo todos os números primos entre 1 e o número digitado.

# %%
lista = []
n = int(input("Escolha um numero inteiro: "))

for i in range(2, n+1):
  for k in range(2,i-1):
    if i%k == 0:
      break
  else:
    lista.append(i)

print(f"O numeros primos entre {n} sao {lista}")
# Out:
# Escolha um numero inteiro: 24
# O numeros primos entre 24 sao [2, 3, 5, 7, 11, 13, 17, 19, 23]

# %% [markdown]
# 6. Escreva um programa que peça uma data informando o dia, mês e ano e determine se ela é uma data válida para uma análise.

# %%
#Coletamos o dia, mês e ano de uma data e fazemos verificações mês a mês,
# verificando se em fevereiro (ano bissexto ou não) o dia nas datas corresponde
#ao que é possível. Meses terminados em 31 ou 30 dias também são analisados
#visando evitar a existência de uma data inválida nos dados.
data = input("Informe o dia, mes e ano(nesse formato dia mes ano): ")
data.split()
# Out:
# Informe o dia, mes e ano(nesse formato dia mes ano): 26 fevereiro 2024
# ['26', 'fevereiro', '2024']

# %% [markdown]
# ##Momento dos projetos

# %% [markdown]
# 7. Para um estudo envolvendo o nível de multiplicação de bactérias em uma colônia, foi coletado o número de bactérias multiplicadas por dia e pode ser observado a seguir: [1.2, 2.1, 3.3, 5.0, 7.8, 11.3, 16.6, 25.1, 37.8, 56.9]. Tendo esses valores, faça um código que gere uma lista contendo o percentual de crescimento de bactérias por dia, comparando o número de bactérias em cada dia com o número de bactérias do dia anterior. Dica: para calcular o percentual de crescimento usamos a seguinte equação: 100 * (amostra_atual - amostra_passada) / (amostra_passada).

# %%
crescimento = [1.2, 2.1, 3.3, 5.0, 7.8, 11.3, 16.6, 25.1, 37.8, 56.9]
perc_cresc = []

for i in range(0,len(crescimento)-1):
  n = ((crescimento[i+1]-crescimento[i])/crescimento[i])*100
  perc_cresc.append(n)

print(perc_cresc)
# Out:
# [75.00000000000001, 57.14285714285713, 51.51515151515152, 55.99999999999999, 44.87179487179488, 46.902654867256636, 51.20481927710843, 50.59760956175297, 50.52910052910053]

# %% [markdown]
# 8. Para uma seleção de produtos alimentícios, precisamos separar o conjunto de IDs dados por números inteiros, sabendo que os produtos com ID par são doces e os com ID ímpar são amargos. Monte um código que colete 10 IDs. Depois, calcule e mostre a quantidade de produtos doces e amargos.

# %%
n = 10
doces = 0
amargos = 0

for i in range(1,n+1):
  id = int(input("Escreva o ID do produto: "))
  if id%2 == 0:
    doces += 1
  else:
    amargos +=1

print(f"O quantidade de doces foi {doces} e amargos foi {amargos}")
# Out:
# Escreva o ID do produto: 5
# Escreva o ID do produto: 4
# Escreva o ID do produto: 6
# Escreva o ID do produto: 8
# Escreva o ID do produto: 5
# Escreva o ID do produto: 1
# Escreva o ID do produto: 2
# Escreva o ID do produto: 3
# Escreva o ID do produto: 7
# Escreva o ID do produto: 9
# O quantidade de doces foi 4 e amargos foi 6

# %% [markdown]
# 9. Desenvolva um programa que informa a nota de um aluno de acordo com suas respostas. Ele deve pedir a resposta de um aluno para cada questão e é preciso verificar se a resposta foi igual ao gabarito. Cada questão vale um ponto e existem alternativas: A, B, C ou D.

# %%
#Criando uma lista para as respostas dos alunos
respostas = []
#Crieando uma lista para o gabarito
gabarito = ["A","C","D","C","B","A","B","D","A","A"]

#Vamos encher a lista de respostas com as respostas do aluno
for i in range(1,len(gabarito)+1):
  respostas.append(input(f"Reposta {i}:"))

#Agora vamos analisar se as respostas batem com o gabarito
pontos = 0

for i in range(0,len(gabarito)):
  if respostas[i]==gabarito[i]:
    pontos += 1
  else:
    continue

print(f"Você acertou {pontos} de dez questoes!")
# Out:
# Reposta 1:A
# Reposta 2:B
# Reposta 3:C
# Reposta 4:C
# Reposta 5:B
# Reposta 6:A
# Reposta 7:D
# Reposta 8:A
# Reposta 9:B
# Reposta 10:A
# Você acertou 5 de dez questoes!

# %% [markdown]
# 10. Um instituto de meteorologia deseja fazer um estudo de temperatura média de cada mês do ano. Para isso, você precisa fazer um código que colete e armazene essas temperaturas médias em uma lista. Depois, calcule a média anual das temperaturas e mostre todas as temperaturas acima da média anual, e em que mês elas ocorreram, mostrando os meses por extenso: Janeiro, Fevereiro, etc.

# %%
temperatura = []

Meses = ["Janeiro","Fevereiro","Marco","Abril","Maio","Junho","Julho","Agosto","Setembro","Outubro","Novembro","Dezembro",]

for i in range(1,13):
  temperatura.append(float(input(f"Informe a temperatura do mes {i}: ")))

media_anual = sum(temperatura)/len(temperatura)

print(f"\nA media anual eh {media_anual}.")
print("\nOs meses que ultrapassaram a media sao: \n")
for i in range(0,12):
  if temperatura[i]>media_anual:
    print(f"{Meses[i]}")
# Out:
# Informe a temperatura do mes 1: 23
# Informe a temperatura do mes 2: 24
# Informe a temperatura do mes 3: 40
# Informe a temperatura do mes 4: 35
# Informe a temperatura do mes 5: 6
# Informe a temperatura do mes 6: 32
# Informe a temperatura do mes 7: 12
# Informe a temperatura do mes 8: 13
# Informe a temperatura do mes 9: 21
# Informe a temperatura do mes 10: 32
# Informe a temperatura do mes 11: 23
# Informe a temperatura do mes 12: 21
#
# A media anual eh 23.5.
#
# Os meses que ultrapassaram a media sao:
#
# Fevereiro
# Marco
# Abril
# Junho
# Outubro

# %% [markdown]
# 11. Uma empresa de e-commerce está interessada em analisar as vendas dos seus produtos. Os dados das vendas foram armazenados em um dicionário:

# %%
{'Produto A': 300, 'Produto B': 80, 'Produto C': 60,
 'Produto D': 200, 'Produto E': 250, 'Produto F': 30}

# %% [markdown]
# Escreva um código que calcule o total de vendas e o produto mais vendido.

# %%
vendas = {'Produto A': 300, 'Produto B': 80, 'Produto C': 60,'Produto D': 200, 'Produto E': 250, 'Produto F': 30}

total_vendas = 0
mais_vendido = 0

for produto in vendas.keys():
  total_vendas += vendas[produto]

  if vendas[produto]> mais_vendido:
    mais_vendido = vendas[produto]
    produto_mais_vendido = produto

print(f"O total de vendas foi {total_vendas} e o produto mais vendido foi o {produto_mais_vendido}")
# Out:
# O total de vendas foi 920 e o produto mais vendido foi o Produto A

# %% [markdown]
# 12. Uma pesquisa de mercado foi feita para decidir qual design de uma marca infantil mais agrada crianças. A pesquisa foi feita e o votos computados podem ser observados abaixo:

# %%
'''
Tabela de votos da marca
Design 1 - 1334 votos
Design 2 - 982 votos
Design 3 - 1751 votos
Design 4 - 210 votos
Design 5 - 1811 votos
'''

# %% [markdown]
# Adapte os dados fornecidos a você para uma estrutura de dicionário e a partir dele, informe o design vencedor e a porcentagem de votos recebidos.

# %%
design = {"Design 1":1334,"Design 2":982,"Design 3":1751,"Design 4":210,"Design 5":1811}

soma_votos = 0
mais_votado = 0

for candidato in design.keys():
  soma_votos += design[candidato]

  if design[candidato]>mais_votado:
    mais_votado = design[candidato]
    vencedor = candidato

porcetagem = (design[vencedor]/soma_votos)*100

print(f"O vencedor foi o {vencedor} com {porcetagem:0.2f}% dos votos")
# Out:
# O vencedor foi o Design 5 com 29.75% dos votos

# %% [markdown]
# 13. Os funcionários de um setor da empresa que você trabalha vão receber um abono correspondente a 10% do seu salário devido ao ótimo desempenho do time. O setor financeiro solicitou sua ajuda para a verificação das consequências financeiras que esse abono irá gerar nos recursos. Assim, foi encaminhada para você uma lista com os salários que receberão o abono: [1172, 1644, 2617, 5130, 5532, 6341, 6650, 7238, 7685, 7782, 7903]. O abono de cada funcionário não pode ser inferior a 200. Em código, transforme cada um dos salários em chaves de um dicionário e o abono de cada salário no elemento. Depois, informe o total de gastos com o abono, quantos funcionários receberam o abono mínimo e qual o maior valor de abono fornecido.

# %%
salarios =  [1172, 1644, 2617, 5130, 5532, 6341, 6650, 7238, 7685, 7782, 7903]

dic_abonos = {}
total_abonos = 0
abonos_minimos = 0
maior_abono = 0

for salario in salarios:
  abono = salario*0.10

  if abono < 200:
    abono = 200

  dic_abonos[salario] = abono

for salario in dic_abonos.keys():
  total_abonos += dic_abonos[salario]

  if dic_abonos[salario] == 200:
    abonos_minimos += 1

  if dic_abonos[salario] > maior_abono:
    maior_abono = dic_abonos[salario]

print(f"A quantidade de abonos minimos foi: {abonos_minimos}")
print(f"O maior abono foi de: {maior_abono:0.2f} reais.")
# Out:
# A quantidade de abonos minimos foi: 2
# O maior abono foi de: 790.30 reais.

# %% [markdown]
# 14. Uma equipe de cientistas de dados está estudando a diversidade biológica em uma floresta. A equipe fez a coleta de informações sobre o número de espécies de plantas e animais em cada área da floresta e armazenaram essas informações em um dicionário. Nele, a chave descreve a área dos dados e os valores nas listas correspondem às espécies de plantas e animais nas áreas, respectivamente.

# %%
{'Área Norte': [2819, 7236],
 'Área Leste': [1440, 9492],
 'Área Sul': [5969, 7496],
 'Área Oeste': [14446, 49688],
 'Área Centro': [22558, 45148]}

# %% [markdown]
#   Escreva um código para calcular a média de espécies por área e identificar a área com a maior diversidade biológica. Dica: use as funções built-in sum() e len().

# %%
areas = {'Área Norte': [2819, 7236],'Área Leste': [1440, 9492],
         'Área Sul': [5969, 7496],'Área Oeste': [14446, 49688],
         'Área Centro': [22558, 45148]}
soma_maior = 0
soma_especies = 0

for area,especie in areas.items():

  soma_especies = sum(especie)

  media = soma_especies/len(especie)

  print(f"A {area} tem em media {media} espécies!")

  if soma_especies > soma_maior:
    soma_maior = soma_especies
    area_maior = area

print(f"\nA area com maior biodiversidadde eh {area_maior}")
# Out:
# A Área Norte tem em media 5027.5 espécies!
# A Área Leste tem em media 5466.0 espécies!
# A Área Sul tem em media 6732.5 espécies!
# A Área Oeste tem em media 32067.0 espécies!
# A Área Centro tem em media 33853.0 espécies!
#
# A area com maior biodiversidadde eh Área Centro

# %% [markdown]
# 15. O setor de RH da sua empresa te pediu uma ajuda para analisar as idades dos funcionários de 4 setores da empresa. Para isso, ele te forneceu os seguintes dados:

# %%
{'Setor A': [22, 26, 30, 30, 35, 38, 40, 56, 57, 65],
 'Setor B': [22, 24, 26, 33, 41, 49, 50, 54, 60, 64],
 'Setor C': [23, 26, 26, 29, 34, 35, 36, 41, 52, 56],
 'Setor D': [19, 20, 25, 27, 34, 39, 42, 44, 50, 65]}

# %% [markdown]
#   Sabendo que cada setor tem 10 funcionários, construa um código que calcule a média de idade de cada setor, a idade média geral entre todos os setores e quantas pessoas estão acima da idade média geral.

# %%
#Primeiro vamos declarar a lista
idades = {'Setor A': [22, 26, 30, 30, 35, 38, 40, 56, 57, 65],
          'Setor B': [22, 24, 26, 33, 41, 49, 50, 54, 60, 64],
          'Setor C': [23, 26, 26, 29, 34, 35, 36, 41, 52, 56],
          'Setor D': [19, 20, 25, 27, 34, 39, 42, 44, 50, 65]}

soma_setor = 0
soma_idades = 0
quantidade = 0

for setor, idade in idades.items():

  media_setor = sum(idade)/len(idade)

  print(f"O {setor} possui uma media de idade de {media_setor}")

  soma_idades += sum(idade)
  quantidade += len(idade)

media_geral = soma_idades/quantidade

print(f"\nA media geral da empresa eh de {media_geral}!")

maiores = 0

for idade in idades.values():
    for k in range(0,len(idade)):
      if idade[k] > media_geral:
        maiores += 1

print(f"\nExistem no total {maiores} funcionarios que passam da media geral de idade.")
# Out:
# O Setor A possui uma media de idade de 39.9
# O Setor B possui uma media de idade de 42.3
# O Setor C possui uma media de idade de 35.8
# O Setor D possui uma media de idade de 36.5
#
# A media geral da empresa eh de 38.625!
#
# Existem no total 18 funcionarios que passam da media geral de idade.
